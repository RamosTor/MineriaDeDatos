# %% [markdown]
# <a href="https://colab.research.google.com/github/RamosTor/MineriaDeDatos/blob/main/people_on_banknotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # People on Banknotes
#
# Whose faces appear on banknotes?
#
# The file `people-on-banknotes.csv` contains data about individuals featured on banknotes from 38 countries. This dataset spans all 22 subregions and sub-subregions of the world, as defined by the United Nations Statistics Division's geoscheme.
#
# It profiles 241 people, detailing their occupations and the year they first appeared on a banknote. Additionally, it includes their year of death — or `NaN` if they were still alive when the dataset was compiled.
#
# Most banknotes were issued after the featured individual’s death. The column `first_death_diff` calculates the difference between the year of their first appearance on a banknote and their year of death (or remains `NaN` if the person was still living at the time of curation).

# %%
# FOR GOOGLE COLAB ONLY.
# Uncomment and run the code below. A dialog will appear to upload files.
# Upload 'people-on-banknotes.csv'.

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0c74afd9-7924-42f2-a284-b025a2419fe9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c74afd9-7924-42f2-a284-b025a2419fe9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('people-on-banknotes.csv')
df
# Out:
#        country            currency                        name gender  \
# 0    Argentina      Argentine Peso                   Eva Perón      F
# 1    Argentina      Argentine Peso        Julio Argentino Roca      M
# 2    Argentina      Argentine Peso  Domingo Faustino Sarmiento      M
# 3    Argentina      Argentine Peso        Juan Manuel de Rosas      M
# 4    Argentina      Argentine Peso             Manuel Belgrano      M
# ..         ...                 ...                         ...    ...
# 274  Venezuela  Venezuelan Bolivar        Francisco de Miranda      M
# 275  Venezuela  Venezuelan Bolivar             Simón Rodrigues      M
# 276  Venezuela  Venezuelan Bolivar             Ezequiel Zamora      M
# 277  Venezuela  Venezuelan Bolivar             Rafael Urdaneta      M
# 278  Venezuela  Venezuelan Bolivar            José Félix Ribas      M
#
#         occupation  value  first_appearance death  first_death_diff  \
# ...

# %% [markdown]
# ### Quick cleaning
#
# The same person can appear on multiple banknotes. Below we drop the `value` column and remove duplicate people.

# %%
df = df.drop(columns=['value'])
df = df.drop_duplicates(subset="name")
df
# Out:
#        country            currency                        name gender  \
# 0    Argentina      Argentine Peso                   Eva Perón      F
# 1    Argentina      Argentine Peso        Julio Argentino Roca      M
# 2    Argentina      Argentine Peso  Domingo Faustino Sarmiento      M
# 3    Argentina      Argentine Peso        Juan Manuel de Rosas      M
# 4    Argentina      Argentine Peso             Manuel Belgrano      M
# ..         ...                 ...                         ...    ...
# 274  Venezuela  Venezuelan Bolivar        Francisco de Miranda      M
# 275  Venezuela  Venezuelan Bolivar             Simón Rodrigues      M
# 276  Venezuela  Venezuelan Bolivar             Ezequiel Zamora      M
# 277  Venezuela  Venezuelan Bolivar             Rafael Urdaneta      M
# 278  Venezuela  Venezuelan Bolivar            José Félix Ribas      M
#
#         occupation  first_appearance death  first_death_diff currency_code
# ...

# %% [markdown]
# ### Project Ideas
#
# - What proportion of individuals featured are male versus female?
# 	- Hint: Use `value_counts(normalize=True)` to calculate percentages.
#
# - Are writers or politicians more commonly depicted?
#
# - What percentage of featured individuals are musicians?
#
# - What percentage of banknotes were issued before the person’s death?
# 	- Hint: Look for negative values or NaN in `first_death_diff`.
#
# - Who is the oldest historical figure in the dataset?
#
# - Which countries feature the oldest historical figures on their banknotes?
# 	- Hint: Group by country and aggregate the year of death using the median. Sort the results.
#
# - What percentage of individuals died at least 100 years before appearing on a banknote?
#
# - Which individuals appeared on a banknote just one year after their death?

# %%
# YOUR CODE HERE (add additional cells as needed)

# Usamos normalize=True para obtener la proporción decimal y multiplicamos por 100
proporcion = df['gender'].value_counts(normalize=True) * 100
print(f"Proporción por género:\n{proporcion}")
# Out:
# Proporción por género:
# gender
# M    78.008299
# F    21.991701
# Name: proportion, dtype: float64

# %%
#2
# Contamos las ocupaciones y comparamos
counts = df['occupation'].value_counts()
escritores = counts.get('Writer', 0)
politicos = counts.get('Politician', 0)

print(f"Escritores: {escritores}")
print(f"Políticos: {politicos}")
print(f"Son más comunes los: {'Escritores' if escritores > politicos else 'Políticos'}")
# Out:
# Escritores: 45
# Políticos: 27
# Son más comunes los: Escritores

# %%
total_personas = len(df)
musicos = len(df[df['occupation'] == 'Musician'])
porcentaje_musicos = (musicos / total_personas) * 100
print(f"El {porcentaje_musicos:.2f}% de los individuos son músicos.")
# Out:
# El 4.98% de los individuos son músicos.

# %%
# Filtramos valores negativos o nulos en la columna de diferencia
antes_muerte = df[(df['first_death_diff'] < 0) | (df['first_death_diff'].isna())]
porcentaje_antes = (len(antes_muerte) / len(df)) * 100
print(f"El {porcentaje_antes:.2f}% de los billetes se emitieron antes de la muerte del personaje.")
# Out:
# El 4.56% de los billetes se emitieron antes de la muerte del personaje.

# %%
# Ahora idxmin() funcionará porque todos son números o NaNs
oldest_idx = df['death'].idxmin()
oldest_figure = df.loc[oldest_idx]

print(f"La figura más antigua es {oldest_figure['name']}, de {oldest_figure['country']}, quien murió en el año {oldest_figure['death']:.0f}.")
# Out:
# La figura más antigua es Hannibal, de Tunisia, quien murió en el año -183.

# %%
# Agrupamos y ordenamos
paises_antiguos = df.groupby('country')['death'].median().sort_values()
print("Top 5 países con personajes más antiguos (según mediana de muerte):")
print(paises_antiguos.head())
# Out:
# Top 5 países con personajes más antiguos (según mediana de muerte):
# country
# South Korea              1560.5
# São Tomé and Príncipe    1779.5
# Ukraine                  1817.5
# United States            1826.0
# Bolivia                  1839.5
# Name: death, dtype: float64

# %%
# Filtramos donde la diferencia es 100 o más
mas_de_100 = (df['first_death_diff'] >= 100).mean() * 100
print(f"El {mas_de_100:.2f}% murió al menos 100 años antes de aparecer en un billete.")
# Out:
# El 33.20% murió al menos 100 años antes de aparecer en un billete.

# %%
# Buscamos exactamente el valor 1 en la diferencia
un_ano = df[df['first_death_diff'] == 1]
print("Personas que aparecieron en un billete un año después de morir:")
print(un_ano[['name', 'country', 'death']])
# Out:
# Personas que aparecieron en un billete un año después de morir:
#                          name      country   death
# 63     Gabriel García Márquez     Colombia  2014.0
# 173  General Murtala Mohammed      Nigeria  1976.0
# 190         Corazon C. Aquino  Philippines  2009.0
# 191           Manuel A. Roxas  Philippines  1948.0
